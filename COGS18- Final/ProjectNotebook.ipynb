# %% [markdown]
# # Medieval Trivia Game

# %% [markdown]
# In this game you will given a mutitude of questions on the subject of the Medieval Era. In this game your objective is to answer all the questions correctly to slay the dragon.
#
# This game allows for the player to experince the diffculties of the trail to the dragon, if they were to answer the trivia question incorrectly. You would only be given three lives to answer only 10 questions to get to the dragon. Along this path to the dragon there will be some obstacles that you would have to face, fatal or nonfatal, which will be determined on how many lives you have. If you are on your last life, meaning you got 2 questions incorrect then you will die from a fatal cause on your path. If you manage to have at least 1 life remaining when you answered 10 questions correctly you face the dragon. The dragon is meant to be a harder, free response, porition of the game. If you even fail to answer one of these 4 questions wrong you die. However, if you answer the 4 questions correctly then you save the town from the dragon. Also, as you answer each question correctly your rank will increase. You can get anything from a peasant, farmer, knight, black knight, or even dragon slayer along your jounrey. You will only be promoted to dragon slayer if you wish to fight and slay the dragon.

# %% [markdown]
# ## Project Code

# %%
from my_module.classes import Player
from my_module.classes import Question
from my_module.classes import Situations

# %%
import random 
starter = Question('\nThe medieval period started with the fall of which major European City?',
                   ['a) Rome', 'b) Constantinople', 'c) London', 'd) Paris'], ['a'])

easy1 = Question('What infection spread mostly to humans by infected fleas that travel through rodents in 1346 to 1353?',
                 ['a) COVID-19', 'b) Black Plague', 'c) Leprosy', 'd) Small-Pox'], ['b'])
easy2 = Question('Who were the poorest of the peasant class?',
                 ['a) bishops', 'b) vassals', 'c) squires', 'd) serfs'], ['d'])
easy3 = Question('Which of the following is the correct hierarchy of Feudal society in Medieval Europe? TOP to BOTTOM',
                 ['a) king, peasants, church officals and nobels, peasants',
                  'b) knights, peasants, church officals and nobels, king',
                  'c) king, knights, church officals and nobels, peasants',
                  'd) peasants, knights, church officals and nobels, king'], ['a'])
easy4 = Question('What is the name of the document that limited a kings power in England?',
                 ['a) Bill of Rights', 'b) Parliament', 'c) Magna Carta', 'd) Oath of Fealty'], ['c'])
easy5 = Question('Most medieval towns were located near what geographical item?',
                 ['a) Rivers', 'b) Mountains', 'c) Deserts', 'd) Forests'], ['a'])

medium1 = Question('William the Conqueror led an invasion into which country?',
                   ['a) France', 'b) Spain', 'c) Italy', 'd) England'], ['d'])
medium2 = Question('Where did most of the learning take place in the middle ages?',
                   ['a) castles', 'b) monastaries', 'c) castles', 'd) manors'], ['b'])
medium3 = Question('During the Middle Ages, often the only people who could read and write were __________.',
                   ['a) priests', 'b) nobles', 'c) lords', 'd) knights'], ['a'])
medium4 = Question('This was the most respected institution in Europe during the Medieval period.',
                   ['a) The Church', 'b) Knighthood', 'c) Feudalism', 'd) Manorialism'], ['a'])
medium5 = Question('Before becoming a knight, a person would have to serve as waht?',
                   ['a) Apostate', 'b) Squire', 'c) Baron', 'd) Bishop'], ['b'])
medium6 = Question('On the feudal manor , in exhange for labor, what did the serfs get in return?',
                   ['a) Nobel Titles', 'b) protections', 'c) ownership of the land', 'd) high wages'], ['b'])

hard1 = Question('To obtain money, The Church initiated how much of an income tax?',
                 ['a) 5%', 'b) 10%', 'c) 20%', 'd) 40%'], ['b'])
hard2 = Question('Charlemagne was the king of which powerful germanic tribe?',
                 ['a) Saxons', 'b) Goths', 'c) Jutes', 'd) Franks'], ['d'])
hard3 = Question('Richard the Lionheart was captured during his return from which crusade?',
                 ['a) The Second', 'b) The Third', 'c) The Fourth', 'd) The Fifth'], ['b'])
hard4 = Question('What was the purpose of The Doomsday Book when it was completed under William the Conqueror?',
                 ['a) Told the end of times', 'b) Outline the goals of england',
                  'c) A land survey', 'd) Separated England from the Catholic Church'], ['c'])
hard5 = Question('Scotland gained its independence after which treaty was signed, ending the first war of Scotish Independance?',
                 ['a) Treaty of Edinburgh-Northampton', 'b) Treaty of Durham', 'c) Treaty of London', 'd) Treaty of Lambeth'], ['a'])
hard6 = Question('One positive impact of the Crusades was?',
                 ['a) Christians reclaimed the Holy Land', 'b) The decline of the power of European Kings',
                  'c) Increased demand for goods from Asia and the Middle East', 'd) Defeat of the Islamic Empires'],
                 ['c'])
hard7 = Question('One negative long-term effect of the Crusades was?',
                 ['a) An increased in trade between Europe and Asia', 'b) Restoration of the Byzantine Empire',
                  'c) A decrease in global trade', 'd) Increased tensions between Christians and Muslims'],
                 ['d'])
hard8 = Question('Which change occured in Europe during the Middle Ages?',
                 ['a) Increase in rural populations', 'b) The power of kings declined',
                  'c) Increase in the popualtion of cities', 'd) Increased in the amount of trade'], ['a'])
hard9 = Question('What important role did the church play in the life of medieval peasants?',
                 ['a) Offered an alternative to the feudal system', 'b) Provided hope in during a hard life',
                  'c) Forced peasants to labor on church land',
                  'd) Encouraged peasants to challenge the authority of the king'], ['b'])

dragon1 = Question('What was the favorite target of the viking when raiding Europe?',
                   [], ['Monasteries', 'Churches', 'Houses of worship'])
dragon2 = Question('The social system of government was called...', [],
                   ['Feudalism', 'The feudal system'])
dragon3 = Question('During what century did the medieval period begin?',
                   [], ['5', '5th', 'The 5th', 'The 5th century', '400\'s', '400', '400s', '476', '476 AD'])
dragon4 = Question('What is the social system by which the Medieval peasents were rendered dependant on their lord?',
                   [], ['Manorialism'])

#Populate the question list
easyQuestions = [easy1, easy2, easy3, easy4, easy5]
mediumQuestions = [medium1, medium2, medium3, medium4, medium5, medium6]
hardQuestions = [hard1, hard2, hard3, hard4, hard5, hard6, hard7, hard8, hard9]
dragonQuestions = [dragon1, dragon2, dragon3, dragon4]

print ('---------------------------------------------------------')
print ('Hello! Welcome to Dragon Slayer: The Return of the Dragon')
print ('---------------------------------------------------------')

print ('It\'s 735 A.D., from the last attack of the dragons, you have been motivated to train and work hard so neither' \
       '\nyou nor the town can suffer again. You took it upon yourself to become the next Dragon Slayer.' \
       '\nYou wait as you train for this next moment to appear, and now the opporitunity has arisen' \
       '\nA new and more deadly dragon appeared killing more than 500 people in the town.' \
       '\nYou and the town fear what this new bread of dragon may do to the remainder of the town. All the countless' \
       '\nhours of training have prepared you for this moment. You seek revenge for those who have lost their lives.' \
       '\n' \
       '\nAre you willing to risk your own life?' \
       '\n' \
       '\nDo you think you have what it takes?' \
       '\n' \
       '\nWill you become the next Dragon Slayer?') 
print ('---------------------------------------------------------')

play = input ('Are you ready to fulfill your destiny and slay the beast, it might get dangerous? y/n: ')

#Controls if the player will begin the game, if not a message is printed and the game ends.
if play.lower () == 'y':
    name = input ('I commend you on your bravery, what is your name?: ')
    player = Player (name)
    print ('\nInteresting... well okay ' + player.name + ', let us start your adventure!')
    print ('Beware, as you start your journey thow need only type the letter in which your persume is the correct answer choice.')
    ready_up = input ('\nAre you sure you wish to continue? y/n: ')
    if ready_up.lower () == 'y':
        print ('\nSplendid, let\'s begin! :)\n')
    else:
        print ('\nThe church will have your head if you wish to turn back, it\'s best if we begin now. Hurry!\n')

    print ('---------------------------------------------------------')
    print ('You will begin your quest as a low tier serf, and you seek to work your way up the heirarchy by collecting'\
          '\nthe coins given by knights and nobels in order for you to gain insight on this new hybrid of a dragon.' \
          '\nA word of caution, your patrons don\'t respond kindly to your incorrect answers. You will only be given' \
          '\nthree chances before they pull you from the quest, and be nothing but a laughing stock as they sever your head for' \
          '\npure entertainment. The questions in which these higher authoritative figures will be asking will increase' \
           '\nor decrease in diffcultly depending on how well you have been doing on your jounrey.' \
           '\nGOOD LUCK :) NO PRESSURE!')
    print ('---------------------------------------------------------')
    
    print ('\nStarting on your quest, you find yourself in middle of a fork. One of which more dangerous than the other.' \
          '\nThe knights and nobles will only tell you to correct path if given the correct answer to the following: ')
    
    #Create the different situation based outcomes.
    situations = Situations()
    
    previous_question = 'STARTER'
    previous_result = False
    
    #Begins with starter question, determining which outcome will be printed depending on if you answer correctly.
    print (starter.question)
    starter.print_choices ()
    answer = input ('CHOICE: ')
    while starter.validate (answer) == False:
        answer = input ('Answer invalid, try again.: ')
        
    if starter.check_answer (answer) == True:
        previous_result = True 
        player.upper_rank ()
        print ('\nSplendid! A map was provided, just continue going right.\n')
    else:
        player.lose_life ()
        print ('\nNOOOO! You took the more treacherous path, your life could now be in danger.\n')
   
    print ('---------------------------------------------------------')
    
     
    counter = 0
    
    #In there would control the main porition of the games questions.
    while counter < 9 and player.lives > 0:
        #In the block, a new question would be choosen based on the difficulty of the pervious question
        #and the players performance on the question. 
        if previous_question == 'EASY':
            if previous_result == True:
                idx = random.randint (0, len(mediumQuestions) - 1)
                question = mediumQuestions [idx]
                del mediumQuestions [idx]
                #The block above chooses a random question from the list and then removed once used.
            else: 
                idx = random.randint (0, len(easyQuestions) - 1)
                question = easyQuestions [idx]
                del easyQuestions [idx]

        elif previous_question == 'MEDIUM'or previous_question == 'STARTER':
            if previous_result == True:
                idx = random.randint (0, len(hardQuestions) - 1) 
                question = hardQuestions [idx]
                del hardQuestions [idx]
                
            else:
                idx = random.randint (0, len(easyQuestions) - 1)
                question = easyQuestions [idx]
                del easyQuestions [idx]
                
        elif previous_question == 'HARD':
            if previous_result == True:
                idx = random.randint (0, len(hardQuestions) - 1)
                question = hardQuestions [idx]
                del hardQuestion [idx]
                
            else:
                idx = random.randint (0, len(mediumQuestions) - 1)
                question = mediumQuestions [idx]
                del mediumQuestions [idx]
        
        #It determines on if we should use a fatal or nonfatal situation
        #based on the players lives. 
        fatal = True
        if player.lives > 1:
            fatal = False
        
        idx = random.randint (0, 9)
        
        if fatal == True:
            #In this block, the situations will be randomized and then deleted after used.
            while idx not in situations.fatal.keys ():
                 idx = random.randint (0, 9)
            scene = situations.fatal [idx]
            del situations.fatal [idx]
            
        else:
            while idx not in situations.nonfatal.keys ():
                 idx = random.randint (0, 9)
            scene = situations.nonfatal [idx]
            del situations.nonfatal [idx]
            
        print (scene [0])
        print ('\n')
        
        print (question.question)
        question.print_choices ()
        answer = input ('CHOICE: ')
        while question.validate (answer) == False:
            answer = input ('Answer invalid, try again.: ')
        
        #If they got the question correctly the player would get a point, causing them to
        #level up in rank and the 'better' situation from that scene would print.
        if question.check_answer (answer) == True:
            previous_result = True 
            player.upper_rank ()
            print ('CORRECT!')
            print (scene [1])
        
        #The player wouldn't rank up but rather so loose a life and it would print out the 
        #'worse' situation from the scene.
        else:
            print ('INCORRECT! CORRECT CHOICE: ' + question.answers [0])
            player.lose_life ()
            print (scene [2])
            
        print ('---------------------------------------------------------')    
        counter = counter + 1
    
    #This controls if the player made it to the dragon portion of the game.
    if player.lives > 0:
        response = input ('CONGRATS WARRIOR! You made it to the dragon alive! You made it with just enough lives to spare.' \
                          '\nBut I do warn you, if you fail to answer these free repsonses correctly, it will result in sudden death.' \
                          '\nYou will have to fathom a slow and painful death, but you would die trying.' \
                          '\nYou have worked hard for this very moment and after long days and nights you now the faith of the town is in' \
                          '\nyour hands. You can turn back now if you wish to remain the rank you are right now, or be promoted to DRAGON SLAYER!' \
                          '\nDo you, ' + player.name + ', wish the slay the dragon?  y/n: ')
        
        if response == 'y':
            print ('I commend you for your bravery warrior! I know this isn\'t easy but we all have faith you will do great! Now show him who\'s boss!')
            win = True 
            counter = 0
            #Asks the dragon questions, and if the player gets a question incorrect
            #the game ends.
            for q in dragonQuestions:
                counter = counter + 1
                answer = input (q.question)
                if q.check_answer (answer) == True:
                    player.upper_rank ()
                    if counter < 4:
                        print ('\nYou\'re still in the fight, keep it up!')
                           
                else:
                    print ()
                    player.info ()
                    win = False
                    break
        
            if win == True:
                player.dragonslayer = True
                print (situations.dragon [1] [0])
                
            else:
                print (situations.dragon [2] [0])
                
            print ('')     
            player.info ()
            
        else:
            print ('')
            print ('After all of this you decide to flea? Weak!')
            player.info ()

    else:
        print ('')
        print ('You were so close...')
        player.info ()   
            
else:
    print ('')
    print ('I hope you change your mind, we need you.')
# Out:
# ---------------------------------------------------------
# Hello! Welcome to Dragon Slayer: The Return of the Dragon
# ---------------------------------------------------------
# It's 735 A.D., from the last attack of the dragons, you have been motivated to train and work hard so neither
# you nor the town can suffer again. You took it upon yourself to become the next Dragon Slayer.
# You wait as you train for this next moment to appear, and now the opporitunity has arisen
# A new and more deadly dragon appeared killing more than 500 people in the town.
# You and the town fear what this new bread of dragon may do to the remainder of the town. All the countless
# hours of training have prepared you for this moment. You seek revenge for those who have lost their lives.
#
# Are you willing to risk your own life?
#
# Do you think you have what it takes?
#
# Will you become the next Dragon Slayer?
# ---------------------------------------------------------
# ...

# %%
from my_module.test_functions import test_player_class
from my_module.test_functions import test_question_class
from my_module.test_functions import test_situation_class

test_player_class ()
test_question_class ()
test_situation_class ()

# %% [markdown]
# #### Extra Credit (*optional*)
#
# 1. I have had no python background before joining this class.
#
# 2. I think my project went above and beyond because I think that i challeneged myself with making a trivia game associated with a story line. Making a game within a trivia took a lot of thinking and planning just so I don't get swamped with an exceessive amount of for loops and nested if else statements. I challeneged myself by trying to figure how to best store the story elements along with the questions so I wouldn't have to hard code each thing. Because I did this, it allows this game to become more scalable. Therefore, I can always add more and more questions hence allowing people to play this over and over again to get some more variety in their questions. Overall, jusy ensuring that everything needed to be printed in the according sections and there were no repeats in questions. It also took some time for me to figure out how to make both mutiple choice questions and free response questions work under the same class. It also took me a while to understand how to have the free reponse answers account for every possible answers the indivudal could type up and not compute it to False when it is in fact True. To add on, it did take a lot of time for me to think about story elements that would best fit my game and the different senarios that could play out if they got the questions right or wrong. I really had to take into account how many lives the player was at, at any given time and to best impliment what would happen next, hence the fatal and nonfatal scenes.
